# %%
import glob
import os
import pandas as pd

from ase.io import read, write
from ase.optimize import BFGS
from ase.constraints import UnitCellFilter
from tensorpotential.calculator import TPCalculator

# --- CONFIG ---
poscar_pattern = "./Laurent/*"   
fmax = 0.02
csv_out = "results.csv"

# %%
# calc = grace_fm('GRACE-1L-OMAT')  
# ['GRACE-1L-MP-r6', 'GRACE-2L-MP-r5', 'GRACE-2L-MP-r6', 'GRACE-FS-OAM', 'GRACE-1L-OAM', 'GRACE-2L-OAM', 'GRACE-FS-OMAT', 'GRACE-1L-OMAT', 'GRACE-2L-OMAT'] 
model_path = "/Users/jcc/.cache/grace/GRACE-1L-OMAT"

# %%
# --- init calculator ---
calc = TPCalculator(model_path)

results = []

for poscar_file in glob.glob(poscar_pattern):
    print(f"==> Traitement {poscar_file}")
    try:
        # lire
        atoms = read(poscar_file, format="cif")
        atoms.set_calculator(calc)

        # énergie initiale
        E_init = atoms.get_potential_energy()

        # relaxer (cellule + positions)
        atoms_ucf = UnitCellFilter(atoms)
        dyn = BFGS(atoms_ucf, logfile="relax.log")  
        dyn.run(fmax=fmax)

        # énergie finale
        E_final = atoms.get_potential_energy()

        # sauvegarder maille relaxée à côté
        #out_file = os.path.join(os.path.dirname(os.path.dirname(poscar_file), "POSCAR_relax")
        out_file = os.path.splitext(poscar_file)[0] + "_relax.cif"
        write(out_file, atoms, format="cif")

        # stocker résultats
        results.append({
            "file": poscar_file,
            "E_init (eV)": E_init,
            "E_final (eV)": E_final,
            "deltaE (eV)": E_final - E_init
        })

    except Exception as e:
        print(f"Erreur sur {poscar_file}: {e}")

# --- écrire CSV ---
df = pd.DataFrame(results)
df.to_csv(csv_out, index=False)
print(f"Résultats écrits dans {csv_out}")
# Out:
# ==> Traitement ./Laurent/JAFBUO06.cif
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/io/cif.py:408: UserWarning: crystal system 'tetragonal' is not interpreted for space group Spacegroup(82, setting=1). This may result in wrong setting!
#   warnings.warn(
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 3 and 17 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 4 and 18 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 5 and 19 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 6 and 20 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 7 and 21 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 8 and 22 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 9 and 23 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 10 and 24 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 11 and 25 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 12 and 26 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 13 and 27 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 14 and 28 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 15 and 29 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 16 and 30 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 1 and 31 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 2 and 32 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 3 and 33 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 4 and 34 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 5 and 35 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 6 and 36 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 7 and 37 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 8 and 38 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 9 and 39 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 10 and 40 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 11 and 41 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 12 and 42 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 13 and 43 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 14 and 44 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 15 and 45 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 16 and 46 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 3 and 47 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 4 and 48 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 5 and 49 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 6 and 50 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 7 and 51 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 8 and 52 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 9 and 53 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 10 and 54 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 11 and 55 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 12 and 56 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 13 and 57 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 14 and 58 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 15 and 59 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 16 and 60 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 62 and 63 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 62 and 64 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 62 and 65 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 67 and 68 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 67 and 69 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /Users/jcc/Software/Anaconda/anaconda3/lib/python3.12/site-packages/ase/spacegroup/spacegroup.py:430: UserWarning: scaled_positions 67 and 70 are equivalent
#   warnings.warn('scaled_positions %d and %d '
# /var/folders/7p/twdtgkrd38n80nhyhlk6k7500000gn/T/ipykernel_46661/877922991.py:11: DeprecationWarning: Please use atoms.calc = calc
#   atoms.set_calculator(calc)
# /var/folders/7p/twdtgkrd38n80nhyhlk6k7500000gn/T/ipykernel_46661/877922991.py:17: FutureWarning: Import UnitCellFilter from ase.filters
#   atoms_ucf = UnitCellFilter(atoms)
# ==> Traitement ./Laurent/JAFBUO07.cif
# Résultats écrits dans results.csv
